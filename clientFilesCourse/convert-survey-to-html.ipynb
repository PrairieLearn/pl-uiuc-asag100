# %%
text = """
The grading results thoroughly explains how the submission provided by Kim is used for grading.
The explanations provided for the grade are reasonable.
The explanations provide concrete references to mistakes in the submission.
I understand how the grader arrived at the final grade for Kim’s submission.
The grading process is applied consistently.
The grading process is free of bias.
The grading process is based on appropriate and relevant criteria.
Kim is able to appeal the grading arrived at by this process.
The grading process adheres to acceptable ethical standards.
Overall, the grading process is fair.
"""
# text = """
# I have a good knowledge in the field of artificial intelligence.
# My most recent research/industry experience/schoolwork includes working with artificial intelligence.
# I am confident interacting with artificial intelligence.
# I understand what the term artificial intelligence means.
# I have dealt with human graders providing inaccurate grades before.
# I have heard about or had experiences with an artificial intelligence system grading my work.
# """

# %%
questions = text.split('\n')
i = 1
for q in questions:
    if not len(q):
        continue
    print(f''' 
<pl-hide-in-panel answer="true">
    <div class=" collapsible-card-header d-flex align-items-center">
        <li>{q}</li>
        <button type="button" class="expand-icon-container btn btn-secondary btn-sm text-nowrap ms-auto"
            data-bs-toggle="collapse" data-bs-target="#q{i}" aria-expanded="true" aria-controls="q{i}"
            aria-label="Toggle q{i}">
        </button>
    </div>
    <div id="q{i}" class="collapse show">
        <p>
            <pl-multiple-choice answers-name="q{i}" fixed-order="true">
                <pl-answer correct="true"> Very low</pl-answer>
                <pl-answer correct="false"> Low</pl-answer>
                <pl-answer correct="false"> Moderate</pl-answer>
                <pl-answer correct="false"> High</pl-answer>
                <pl-answer correct="false"> Very high</pl-answer>
            </pl-multiple-choice>
        </p>
    </div>
</pl-hide-in-panel>''')
    i += 1
# Out:
#
# <pl-hide-in-panel answer="true">
#     <div class=" collapsible-card-header d-flex align-items-center">
#         <li>The grading results thoroughly explains how the submission provided by Kim is used for grading.</li>
#         <button type="button" class="expand-icon-container btn btn-secondary btn-sm text-nowrap ms-auto"
#             data-bs-toggle="collapse" data-bs-target="#q1" aria-expanded="true" aria-controls="q1"
#             aria-label="Toggle q1">
#         </button>
#     </div>
#     <div id="q1" class="collapse show">
#         <p>
#             <pl-multiple-choice answers-name="q1" fixed-order="true">
#                 <pl-answer correct="true"> Very low</pl-answer>
#                 <pl-answer correct="false"> Low</pl-answer>
#                 <pl-answer correct="false"> Moderate</pl-answer>
#                 <pl-answer correct="false"> High</pl-answer>
#                 <pl-answer correct="false"> Very high</pl-answer>
#             </pl-multiple-choice>
# ...
